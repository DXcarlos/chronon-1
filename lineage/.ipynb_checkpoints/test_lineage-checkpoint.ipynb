# %%
from pyspark.sql import SparkSession

# Create Spark session
spark = SparkSession.builder \
    .appName("MyApp") \
    .config("spark.driver.bindAddress", "127.0.0.1") \
    .config("spark.driver.host", "127.0.0.1") \
    .getOrCreate()

# Example usage
df = spark.createDataFrame([(1, "Alice"), (2, "Bob")], ["id", "name"])
df.show()
# Out:
# 25/07/05 16:39:42 WARN SparkContext: Another SparkContext is being constructed (or threw an exception in its constructor). This may indicate an error, since only one SparkContext should be running in this JVM (see SPARK-2243). The other SparkContext was created at:
# org.apache.spark.api.java.JavaSparkContext.<init>(JavaSparkContext.scala:58)
# java.base/jdk.internal.reflect.NativeConstructorAccessorImpl.newInstance0(Native Method)
# java.base/jdk.internal.reflect.NativeConstructorAccessorImpl.newInstance(NativeConstructorAccessorImpl.java:77)
# java.base/jdk.internal.reflect.DelegatingConstructorAccessorImpl.newInstance(DelegatingConstructorAccessorImpl.java:45)
# java.base/java.lang.reflect.Constructor.newInstanceWithCaller(Constructor.java:499)
# java.base/java.lang.reflect.Constructor.newInstance(Constructor.java:480)
# py4j.reflection.MethodInvoker.invoke(MethodInvoker.java:247)
# py4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:374)
# py4j.Gateway.invoke(Gateway.java:238)
# py4j.commands.ConstructorCommand.invokeConstructor(ConstructorCommand.java:80)
# py4j.commands.ConstructorCommand.execute(ConstructorCommand.java:69)
# py4j.ClientServerConnection.waitForCommands(ClientServerConnection.java:182)
# py4j.ClientServerConnection.run(ClientServerConnection.java:106)
# java.base/java.lang.Thread.run(Thread.java:840)
# +---+-----+
# | id| name|
# +---+-----+
# |  1|Alice|
# |  2|  Bob|
# +---+-----+

# %%
cnt = 0
for line in open('final_pivot.sql', 'r').readlines():
    cnt = cnt + 1
    print(cnt, ': ', line.rstrip())
# Out:
# 1 :
# 2 :  with eligible as (
# 3 :      select distinct
# 4 :          mmxRequestUUID
# 5 :      from default_iceberg.search.search_ranking_v5_intl_listing_with_labels
# 6 :      where _DATE between 'start_date' and 'end_date'
# 7 :      and label__search_labels_attributions_v2_tight_attributions_last_1d is not null
# 8 :  ),
# 9 :  filtered_join_listing as (
# 10 :      select
# 11 :          source.browser_id,
# 12 :          source.listing_id,
# 13 :          source.mmxRequestUUID,
# 14 :          source.pipeline,
# 15 :          source.placement,
# 16 :          source.query,
# 17 :          source.search_fulfillment_edd_v1_max_calendar_days_intl_orders_keys_last,
# 18 :          source.search_fulfillment_edd_v1_max_calendar_days_intl_orders_values_last,
# 19 :          source.ts,
# 20 :          source.userCountry,
# 21 :          source.user_id,
# 22 :          source._DATE,
# 23 :          source.mmxRequestUUID as request_id
# 24 :      from default_iceberg.search.search_ranking_v5_intl_listing_with_labels source
# 25 :      left semi join eligible on eligible.mmxRequestUUID = source.mmxRequestUUID
# 26 :      where _DATE between 'start_date' and 'end_date'
# 27 :  ),
# 28 :  filtered_join_context as (
# 29 :      select
# 30 :          search_beacons_user_browser_cart_adds_v2_listing_id_last50_30d,
# 31 :          mmxRequestUUID,
# 32 :          _DATE
# 33 :      from search.search_ranking_v5_intl_context
# 34 :      where _DATE between 'start_date' and 'end_date'
# 35 :  ),
# 36 :  hardware_type as (
# 37 :      select
# 38 :          mmxRequestUUID,
# 39 :          any_value(primaryHardwareType) as primaryHardwareType,
# 40 :          _DATE
# 41 :      from search.search_attributions_tight_v2
# 42 :      where _DATE between 'start_date' and 'end_date'
# 43 :      group by mmxRequestUUID, _DATE
# 44 :  ),
# 45 :  values_ as (
# 46 :      select
# 47 :          ls.browser_id as `browser_id`,
# 48 :          ls.listing_id as `listing_id`,
# 49 :          ls.mmxRequestUUID as `mmxRequestUUID`,
# 50 :          ls.pipeline as `pipeline`,
# 51 :          ls.placement as `placement`,
# 52 :          ls.query as `query`,
# 53 :          ls.search_fulfillment_edd_v1_max_calendar_days_intl_orders_keys_last as `search_fulfillment_edd_v1_max_calendar_days_intl_orders_keys_last`,
# 54 :          ls.search_fulfillment_edd_v1_max_calendar_days_intl_orders_values_last as `search_fulfillment_edd_v1_max_calendar_days_intl_orders_values_last`,
# 55 :          ls.ts as `ts`,
# 56 :          ls.userCountry as `userCountry`,
# 57 :          ls.user_id as `user_id`,
# 58 :          ls._DATE as _DATE,
# 59 :          coalesce(ls.label__search_labels_attributions_v2_tight_attributions_last_1d, array('no_event')) as label__search_labels_attributions_v2_tight_attributions_last_1d,
# 60 :          ht.primaryHardwareType
# 61 :      from filtered_join_listing as ls
# 62 :      join hardware_type as ht
# 63 :          on (ls.request_id = ht.mmxRequestUUID
# 64 :          and ls._DATE = ht._DATE)
# 65 :  ),
# 66 :  filtered_raw_logs as (
# 67 :      select
# 68 :          mmxRequestUUID,
# 69 :          candidateInfo,
# 70 :          contextualInfo,
# 71 :          requestInfo,
# 72 :          listing_ids,
# 73 :          placement,
# 74 :          pipeline,
# 75 :          _DATE
# 76 :      from polaris_catalog.search.search_logging_v5_logs
# 77 :      where _DATE between 'start_date' and 'end_date'
# 78 :  ),
# 79 :  positions as (
# 80 :      select
# 81 :          mmxRequestUUID,
# 82 :          position,
# 83 :          listing_id,
# 84 :          _DATE
# 85 :      from filtered_raw_logs as frl
# 86 :      lateral view posexplode(listing_ids) as position, listing_id
# 87 :  ),
# 88 :  collected as (
# 89 :      select
# 90 :          mmxRequestUUID,
# 91 :          first(ts) as ts,
# 92 :          first(_DATE) as _DATE,
# 93 :          first(pipeline) as pipeline,
# 94 :          case
# 95 :              when max(
# 96 :                  exists(label__search_labels_attributions_v2_tight_attributions_last_1d, x -> x = 'click')
# 97 :                  and exists(label__search_labels_attributions_v2_tight_attributions_last_1d, x -> x = 'cart_add')
# 98 :                  and exists(label__search_labels_attributions_v2_tight_attributions_last_1d, x -> x = 'purchase')
# 99 :              ) = true then 'purchase'
# 100 :              when max(
# 101 :                  exists(label__search_labels_attributions_v2_tight_attributions_last_1d, x -> x = 'click')
# 102 :                  and exists(label__search_labels_attributions_v2_tight_attributions_last_1d, x -> x = 'cart_add')
# 103 :              ) = true then 'cart_add'
# 104 :              when max(
# 105 :                  exists(label__search_labels_attributions_v2_tight_attributions_last_1d, x -> x = 'click')
# 106 :              ) = true then 'click'
# 107 :              else 'no_event'
# 108 :          end as attribution_type,
# 109 :          named_struct(
# 110 :              'id', collect_list(mmxRequestUUID),
# 111 :              'userCountry', collect_list(userCountry),
# 112 :              'placement', collect_list(placement),
# 113 :              'primaryHardwareType', collect_list(primaryHardwareType),
# 114 :              'search_fulfillment_edd_v1_max_calendar_days_intl_orders_keys_last', collect_list(named_struct('value', search_fulfillment_edd_v1_max_calendar_days_intl_orders_keys_last)),'search_fulfillment_edd_v1_max_calendar_days_intl_orders_values_last', collect_list(named_struct('value', search_fulfillment_edd_v1_max_calendar_days_intl_orders_values_last)),'label__search_labels_attributions_v2_tight_attributions_last_1d', collect_list(named_struct('value', label__search_labels_attributions_v2_tight_attributions_last_1d))
# 115 :          ) as features
# 116 :      from (
# 117 :          select
# 118 :              values_.mmxRequestUUID,
# 119 :              values_.listing_id,
# 120 :              values_._DATE
# 121 :          from values_
# 122 :          join positions
# 123 :              on values_.mmxRequestUUID = positions.mmxRequestUUID
# 124 :              and values_.listing_id = positions.listing_id
# 125 :              and values_._DATE = positions._DATE
# 126 :          order by values_.mmxRequestUUID, positions.position
# 127 :      )
# 128 :      group by mmxRequestUUID
# 129 :  )
# 130 :  select
# 131 :      c.ts,
# 132 :      frl._DATE,
# 133 :      frl.pipeline,
# 134 :      attribution_type,
# 135 :      transform(features.label__search_labels_attributions_v2_tight_attributions_last_1d, f -> f.value) as attributions,
# 136 :      features.id as id,
# 137 :      features.id as requestUUID,
# 138 :      features.userCountry as userCountry,
# 139 :      features.placement as placement,
# 140 :      features.primaryHardwareType as primaryHardwareType,
# 141 :      transform(features.search_fulfillment_edd_v1_max_calendar_days_intl_orders_keys_last, x -> x.value) as `candidateInfo.ziplineInfo.search_fulfillment_edd_v1_max_calendar_days_intl_orders_keys_last`,
# 142 :  transform(features.search_fulfillment_edd_v1_max_calendar_days_intl_orders_values_last, x -> x.value) as `candidateInfo.ziplineInfo.search_fulfillment_edd_v1_max_calendar_days_intl_orders_values_last`,
# 143 :  transform(features.label__search_labels_attributions_v2_tight_attributions_last_1d, x -> x.value) as `label__search_labels_attributions_v2_tight_attributions_last_1d`,
# 144 :      frl.mmxRequestUUID as `mmxRequestUUID`,
# 145 :      ctx.search_beacons_user_browser_cart_adds_v2_listing_id_last50_30d as `contextualInfo[name=browser].ziplineInfo.search_beacons_user_browser_cart_adds_v2_listing_id_last50_30d`,
# 146 :      frl.candidateInfo.candidateInfo_docInfo_listingInfo_activeListingBasics_countryName as `candidateInfo.docInfo.listingInfo.activeListingBasics.countryName`,
# 147 :      frl.requestInfo.clientProvidedInfo_browser_canPerso as `clientProvidedInfo.browser.canPerso`,
# 148 :      frl.contextualInfo.contextualInfo_name_browser_rivuletBrowserInfo_timeseries_recentlyCartaddedListingIds50FV1_listingId as `contextualInfo[name=browser].rivuletBrowserInfo.timeseries.recentlyCartaddedListingIds50FV1#listingId`,
# 149 :      array(
# 150 :          'contextualInfo[name=browser].ziplineInfo.search_beacons_user_browser_cart_adds_v2_listing_id_last50_30d',
# 151 :          'contextualInfo[name=browser].ziplineInfo.search_beacons_user_browser_cart_adds_v2_shop_id_last50_30d'
# 152 :      ) as to_expand,
# 153 :      size(features.id) as candidate_count
# 154 :  from collected c
# 155 :  join filtered_raw_logs as frl
# 156 :      on c.mmxRequestUUID = frl.mmxRequestUUID
# 157 :      and c._DATE = frl._DATE
# 158 :  join filtered_join_context as ctx
# 159 :      on c.mmxRequestUUID = ctx.mmxRequestUUID
# 160 :      and c._DATE = ctx._DATE
# 161 :

# %%
sqlglot.parse_one(query)
# Out:
# ---------------------------------------------------------------------------
# ParseError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 sqlglot.parse_one(query)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sqlglot/__init__.py:139, in parse_one(sql, read, dialect, into, **opts)
#     137     result = dialect.parse_into(into, sql, **opts)
#     138 else:
# --> 139     result = dialect.parse(sql, **opts)
#     141 for expression in result:
#     142     if not expression:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sqlglot/dialects/dialect.py:1022, in Dialect.parse(self, sql, **opts)
#    1021 def parse(self, sql: str, **opts) -> t.List[t.Optional[exp.Expression]]:
# -> 1022     return self.parser(**opts).parse(self.tokenize(sql), sql)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sqlglot/parser.py:1592, in Parser.parse(self, raw_tokens, sql)
#    1578 def parse(
#    1579     self, raw_tokens: t.List[Token], sql: t.Optional[str] = None
#    1580 ) -> t.List[t.Optional[exp.Expression]]:
#    1581     """
#    1582     Parses a list of tokens and returns a list of syntax trees, one tree
#    1583     per parsed SQL statement.
#    (...)
#    1590         The list of the produced syntax trees.
#    1591     """
# -> 1592     return self._parse(
#    1593         parse_method=self.__class__._parse_statement, raw_tokens=raw_tokens, sql=sql
#    1594     )
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sqlglot/parser.py:1661, in Parser._parse(self, parse_method, raw_tokens, sql)
#    1658 self._tokens = tokens
#    1659 self._advance()
# -> 1661 expressions.append(parse_method(self))
#    1663 if self._index < len(self._tokens):
#    1664     self.raise_error("Invalid expression / Unexpected token")
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sqlglot/parser.py:1902, in Parser._parse_statement(self)
#    1899     return self._parse_command()
#    1901 expression = self._parse_expression()
# -> 1902 expression = self._parse_set_operations(expression) if expression else self._parse_select()
#    1903 return self._parse_query_modifiers(expression)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sqlglot/parser.py:3189, in Parser._parse_select(self, nested, table, parse_subquery_alias, parse_set_operation, consume_pipe)
#    3181 def _parse_select(
#    3182     self,
#    3183     nested: bool = False,
#    (...)
#    3187     consume_pipe: bool = True,
#    3188 ) -> t.Optional[exp.Expression]:
# -> 3189     query = self._parse_select_query(
#    3190         nested=nested,
#    3191         table=table,
#    3192         parse_subquery_alias=parse_subquery_alias,
#    3193         parse_set_operation=parse_set_operation,
#    3194     )
#    3196     if (
#    3197         consume_pipe
#    3198         and self._match(TokenType.PIPE_GT, advance=False)
#    3199         and isinstance(query, exp.Query)
#    3200     ):
#    3201         query = self._parse_pipe_syntax_query(query)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sqlglot/parser.py:3213, in Parser._parse_select_query(self, nested, table, parse_subquery_alias, parse_set_operation)
#    3206 def _parse_select_query(
#    3207     self,
#    3208     nested: bool = False,
#    (...)
#    3211     parse_set_operation: bool = True,
#    3212 ) -> t.Optional[exp.Expression]:
# -> 3213     cte = self._parse_with()
#    3215     if cte:
#    3216         this = self._parse_statement()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sqlglot/parser.py:3348, in Parser._parse_with(self, skip_with_token)
#    3346 expressions = []
#    3347 while True:
# -> 3348     cte = self._parse_cte()
#    3349     if isinstance(cte, exp.CTE):
#    3350         expressions.append(cte)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sqlglot/parser.py:3391, in Parser._parse_cte(self)
#    3386 else:
#    3387     materialized = None
#    3389 cte = self.expression(
#    3390     exp.CTE,
# -> 3391     this=self._parse_wrapped(self._parse_statement),
#    3392     alias=alias,
#    3393     materialized=materialized,
#    3394     comments=comments,
#    3395 )
#    3397 values = cte.this
#    3398 if isinstance(values, exp.Values):
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sqlglot/parser.py:7249, in Parser._parse_wrapped(self, parse_method, optional)
#    7247 parse_result = parse_method()
#    7248 if wrapped:
# -> 7249     self._match_r_paren()
#    7250 return parse_result
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sqlglot/parser.py:8040, in Parser._match_r_paren(self, expression)
#    8038 def _match_r_paren(self, expression: t.Optional[exp.Expression] = None) -> None:
#    8039     if not self._match(TokenType.R_PAREN, expression=expression):
# -> 8040         self.raise_error("Expecting )")
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sqlglot/parser.py:1705, in Parser.raise_error(self, message, token)
#    1693 error = ParseError.new(
#    1694     f"{message}. Line {token.line}, Col: {token.col}.\n"
#    1695     f"  {start_context}\033{highlight}\033{end_context}",
#    (...)
#    1701     end_context=end_context,
#    1702 )
#    1704 if self.error_level == ErrorLevel.IMMEDIATE:
# -> 1705     raise error
#    1707 self.errors.append(error)
#
# ParseError: Expecting ). Line 47, Col: 36.
#   'end_date'
#     group by mmxRequestUUID, _DATE
# ),
# values_ as (
#     select
#         ls.browser_id as `browser_id`,
#         ls.listing_id as `listing_id`,
#         ls.mmxRequestUUID as `mmxRequestUUID`,
#         ls.
